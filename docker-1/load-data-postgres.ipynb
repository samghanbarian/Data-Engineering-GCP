# %%
# !pip install pandas sqlalchemy psycopg2
# Out:
# ...
#   Using cached pandas-2.0.0-cp311-cp311-win_amd64.whl (11.2 MB)
# ...
#      ---------------------------------------- 2.0/2.0 MB 1.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 502.3/502.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 14.8/14.8 MB 2.9 MB/s eta 0:00:00
# ...
#      ------------------------------------ 192.5/192.5 kB 969.2 kB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: C:\Users\arsen\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\engine\base.py:3275, in Engine.raw_connection(self)
#    3254 """Return a "raw" DBAPI connection from the connection pool.
#    3255
#    3256 The returned object is a proxied version of the DBAPI
#    (...)
#    3273
#    3274 """
# -> 3275 return self.pool.connect()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sqlalchemy\pool\base.py:455, in Pool.connect(self)
# ...

# %%
q = """ 
select 1 as num
"""
pd.read_sql(q,con= engine)
# Out:
#    num
# 0    1

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

pd.read_sql(query, con=engine)
# Out:
#   schemaname          tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  Yellow_taxi_trips       root       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
# !pip install pyarrow
# Out:
# ...
#      ---------------------------------------- 20.5/20.5 MB 3.8 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: C:\Users\arsen\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pyarrow.parquet as pq

# %%
trips = pq.read_table("yellow_tripdata_2023-01.parquet")

# %%
df = trips.to_pandas()

# %%
df.head(100)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0          2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0  \
# 1          2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2          2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3          1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4          2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2023-01-01 00:20:38   2023-01-01 00:21:26              1.0
# 96         2  2023-01-01 00:09:16   2023-01-01 00:30:17              1.0
# 97         2  2023-01-01 00:46:56   2023-01-01 00:59:16              1.0
# 98         2  2023-01-01 00:10:50   2023-01-01 00:20:19              1.0
# 99         2  2023-01-01 00:27:35   2023-01-01 00:37:49              1.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %%
i = 0
chunck = 200
df1 = df[i:i+chunck]

# %%
len(df1)
# Out:
# 200

# %%
df1.iloc[199]
# Out:
# VendorID                                   2
# tpep_pickup_datetime     2023-01-01 00:13:54
# tpep_dropoff_datetime    2023-01-01 00:19:01
# passenger_count                          1.0
# trip_distance                            0.5
# RatecodeID                               1.0
# store_and_fwd_flag                         N
# PULocationID                              79
# DOLocationID                              79
# payment_type                               1
# fare_amount                              6.5
# extra                                    1.0
# mta_tax                                  0.5
# tip_amount                               2.3
# tolls_amount                             0.0
# improvement_surcharge                    1.0
# total_amount                            13.8
# congestion_surcharge                     2.5
# airport_fee                              0.0
# Name: 199, dtype: object

# %%
df.to_sql()

# %%
print(pd.io.sql.get_schema(df,name = 'yellow_taxi_data',con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53),
# 	airport_fee FLOAT(53)
# )

# %%
from time import time

# %%
chunck = 300000
i , j= 0

while j <= (len(df)%chunck - 1):
    df1 = df[i:i+chunck]
    t_start = time()
    df1.to_sql(name = 'yellow_taxi_trips', con=engine,if_exists='append')
    print("ingest 1 completed")
    t_end = time()
    print("it took %.3f t_end-t_start seconds to finish the job"%(t_end-t_start))
    i = i + chunck
    j += 1
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)
#
#
# ...

# %%
ingest(df)
